# %%
import csv
import 
import json as json
import pandas as pd
from IPython.display import display, HTML
chiroptera_dataset_filepath = "./Data/note_chiroptera_database.csv"

# %%
def read_data_file(file_path):
    dataset = []
    with open(file_path, "r") as data_file:
        csv_reader = csv.reader(data_file)
        header = csv_reader.next()
        for row in csv_reader:
            dataset.append(row)
    df_dataset = pd.DataFrame(dataset, columns = header)
    return df_dataset

# %%
def processEndemicStatus(rawData):
    ENDEMIC_STATUS ='endemic'
    NON_ENDEMIC_STATUS ='non endemic'
    result = rawData.split('to')[0].lower().rstrip()
    endemicStatus = None
    
    if (result == ENDEMIC_STATUS):
        endemicStatus = True
    elif(result == NON_ENDEMIC_STATUS):
        endemicStatus = False
    return endemicStatus

def processEndemicRegion(rawData):
    DIRECTION = ['south','north','west','east']
    REGION = ['africa', 'asia', 'america', 'europe','antartica']
    result = rawData.split(' ')
    direction = ''
    region =''
    for x in result:
        if(x.lower() in DIRECTION):
            direction = x
        elif(x.lower() in REGION):
            region = x
    return (direction+region)

def isRegionAvailable(data):
    REGION = ['africa', 'asia', 'america', 'europe','antartica']
    for x in REGION:
        #print(x)
        if(x in data.lower()):
            
            return True
    return False

def processEndemicSubRegion(rawData):
    result = ''
    if ('(' in rawData):
        result = rawData.split('(')[1].strip(') .')
    elif(isRegionAvailable(rawData) == False): # To Handle case 'Endemic to India'
        resultList = rawData.split('to')
        if(len(resultList) > 2):
           result = resultList[1].strip(' ')
        
    return json.dumps(result.split(','))
    

df_chiroptera = read_data_file(chiroptera_dataset_filepath)
endemic_status_data = df_chiroptera["Endemic status"]
df_chiroptera['IsEndemic'] = endemic_status_data.apply(lambda x:processEndemicStatus(x))
df_chiroptera['Endemic Region'] = endemic_status_data.apply(lambda x:processEndemicRegion(x))
df_chiroptera['Endemic SubRegion'] = endemic_status_data.apply(lambda x:processEndemicSubRegion(x))
temp ='Endemic to South Asia'
#print(df_chiroptera.index)
print(df_chiroptera.index+1)
#display(processEndemicSubRegion(temp))
display(HTML(df_chiroptera.to_html()))
# Out:
# RangeIndex(start=1, stop=126, step=1)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>﻿Genus + Species + Sub species + Authority</th>
#       <th>Checklist code</th>
#       <th>Endemic status</th>
#       <th>Status with Criteria (South Asia)</th>
#       <th>National Status - 1</th>
#       <th>Map file</th>
#       <th>Synonyms</th>
#       <th>Common names</th>
#       <th>Family</th>
#       <th>Habit</th>
#       <th>Habitat</th>
#       <th>Niche</th>
#       <th>Distribution</th>
#       <th>Global</th>
#       <th>South Asia</th>
#       <th>Extent of Occurrence</th>
#       <th>Area of Occupancy</th>
#       <th>Locations/subpopulations</th>
#       <th>Habitat status</th>
#       <th>Data source - 1</th>
#       <th>Threats</th>
#       <th>Threats to the taxon</th>
#       <th>Trade</th>
#       <th>Data source - 2</th>
#       <th>Population</th>
#       <th>Generation time</th>
#       <th>Mature individuals</th>
#       <th>Population trend</th>
#       <th>Data source - 3</th>
#       <th>Red List 2001 Status derived in the workshop</th>
#       <th>Ver. 3.1:</th>
#       <th>1997 CAMP (Ver. 2.3):</th>
#       <th>National Status</th>
#       <th>Uncertainty</th>
#       <th>Other status</th>
#       <th>Red List of Threatened Species (2000)</th>
#       <th>Microchiroptera Action Plan (Global)</th>
#       <th>Old World Fruit Bats Action Plan (Global)</th>
#       <th>CITES</th>
#       <th>Known presence in Protected Areas</th>
#       <th>Recommendations</th>
#       <th>Research</th>
#       <th>Management</th>
#       <th>Captive breeding</th>
#       <th>Comments</th>
#       <th>Sources</th>
#       <th>Compilers</th>
#       <th>Reviewers</th>
#       <th>Recent Field Studies</th>
#       <th>IsEndemic</th>
#       <th>Endemic Region</th>
#       <th>Endemic SubRegion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Areilulus circumdatus(Temminck, 1840)</td>
#       <td>BAT1</td>
#       <td>Non Endemic to South Asia</td>
#       <td>LEAST CONCERN in South Asia</td>
#       <td>India Least Concern \nNepal Near Threatened</td>
#       <td>Areilulus_circumdatus_map.pdf</td>
#       <td>Pipistrellus (Arielulus) circumdatus  (Temminc...</td>
#       <td>Black-gilded Pipistrelle</td>
#       <td>Vespertilionidae</td>
#       <td></td>
#       <td></td>
#       <td>At least 2031m.</td>
#       <td></td>
#       <td>China, India, Myanmar, Nepal</td>
#       <td>INDIA: Assam: Guwahati University; Meghalaya: ...</td>
#       <td>&gt; 20,000 sq km</td>
#       <td>&gt; 2,000 sq km</td>
#       <td>4 / 2. Fragmented.</td>
#       <td>Stable</td>
#       <td>Literature, field study; inferred, observed</td>
#       <td></td>
#       <td>Not known</td>
#       <td></td>
#       <td></td>
#       <td>4-6 years</td>
#       <td>Not known</td>
#       <td>Not known</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>LEAST CONCERN</td>
#       <td></td>
#       <td>India Least Concern \nNepal Near Threatened</td>
#       <td>Assessed based on evidence and on the consensu...</td>
#       <td></td>
#       <td>Not Evaluated</td>
#       <td>Lower Risk least concern</td>
#       <td></td>
#       <td>Not listed</td>
#       <td>None</td>
#       <td></td>
#       <td>Survey, ecology.</td>
#       <td>Habitat management, monitoring.</td>
#       <td>Techniques not known at all.</td>
#       <td>The species Pipistrellus (Arielulus) circumdat...</td>
#       <td>Bates &amp; Harrison, 1997; Hutson  et al., 2001; ...</td>
#       <td>A.C. Girish, J.K. Immanuel, S. Kandula, V.S. K...</td>
#       <td>Rest of the participants</td>
#       <td>A. Ali, Gauhati University, Jalukbari, Assam, ...</td>
#       <td>False</td>
#       <td>SouthAsia</td>
#       <td>[""]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Asellia tridens(Geoffroy, E., 1813)</td>
#       <td>BAT2</td>
#       <td>Non Endemic to South Asia</td>
#       <td>NOT EVALUATED  in South Asia</td>
#       <td></td>
#       <td></td>
#       <td>Rhinolophus tridens  Geoffroy, E. 1813\nPhyllo...</td>
#       <td>Trident Bat</td>
#       <td>Hipposideridae</td>
#       <td>Gregarious and colonial</td>
#       <td>Arid areas</td>
#       <td>Crevices or in the roofs of cliffs</td>
#       <td></td>
#       <td>West Africa, Arabia and Iran to Pakistan</td>
#       <td>PAKISTAN: Baluchistan: Panjgur, Nushki; Sind: ...</td>
#       <td>Not known</td>
#       <td>Not known</td>
#       <td>Not known</td>
#       <td>Not known</td>
#       <td></td>
#       <td></td>
#       <td>Not known</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>Not known</td>
#       <td>Not known</td>
#       <td>Not known</td>
#       <td></td>
#       <td></td>
#       <td>NOT EVALUATED</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>Lower Risk least concern</td>
#       <td></td>
#       <td>Not listed</td>
#       <td>None</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>Anderson, 1881; Bates &amp; Harrison, 1997; Geoffr...</td>
#       <td></td>
#       <td></td>
#       <td>None</td>
#       <td>False</td>
#       <td>SouthAsia</td>
#       <td>[""]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Barbastella leucomelas&lt;/I&gt;(Cretzschmar, 1830/31)</td>
#       <td>BAT3</td>
#       <td>Non Endemic to South Asia</td>
#       <td>NEAR THREATENED  in South Asia</td>
#       <td>India Near Threatened \nNepal Near Threatened ...</td>
#       <td>Barbastella_leucomelas_map.pdf</td>
#       <td>Vespertilio leucomelas  Cretzschmar, 1830/31\n...</td>
#       <td>Eastern Barbastelle</td>
#       <td>Vespertilionidae</td>
#       <td>Solitary, nocturnal</td>
#       <td>Himalayan moist temperate forest and dry conif...</td>
#       <td>Caves, tunnels, crevices, tree hollows, bark. ...</td>
#       <td></td>
#       <td>Afghanistan, India, Iran, \nNepal: Annapurna c...</td>
#       <td>AFGHANISTAN: Kalat-us-Seraj, Kamdesh, Wazi Bag...</td>
#       <td>&gt; 20,000 sq km</td>
#       <td>&gt; 2,000 sq km</td>
#       <td>Approximately 20 / not known. Not fragmented.</td>
#       <td>Decrease in area &lt; 10% in the last 5 years due...</td>
#       <td>Field study, literature; inferred</td>
#       <td></td>
#       <td>Habitat loss, habitat alteration in the past, ...</td>
#       <td>Not in trade</td>
#       <td>Field study; inferred.</td>
#       <td></td>
#       <td>Not known</td>
#       <td>Not known</td>
#       <td>Not known</td>
#       <td></td>
#       <td></td>
#       <td>NEAR THREATENED \nAlthough widely distributed,...</td>
#       <td></td>
#       <td>India Near Threatened \nNepal Near Threatened ...</td>
#       <td>Assessed based on evidence, inference, precaut...</td>
#       <td></td>
#       <td>Not Evaluated</td>
#       <td>Lower Risk least concern</td>
#       <td></td>
#       <td>Not listed</td>
#       <td>NEPAL: Annapurna Conservation Area, Makalu Bar...</td>
#       <td></td>
#       <td>Survey</td>
#       <td>Monitoring</td>
#       <td>Propagation techniques not known at all.</td>
#       <td>Hibernates in winter. Shrestha has observed 15...</td>
#       <td>Bates &amp; Harrison, 1997; Cretzschmar, 1826-31; ...</td>
#       <td>S. Mistry, M. Muni, K.R. Senacha, T.K. Shresth...</td>
#       <td>Rest of the participants</td>
#       <td>T.K. Shrestha in Western Nepal, 1997-1999, Mam...</td>
#       <td>False</td>
#       <td>SouthAsia</td>
#       <td>[""]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Coelops frithii Blyth, 1848</td>
#       <td>BAT4</td>
#       <td>Non Endemic to South Asia</td>
#       <td>NEAR THREATENED  in South Asia</td>
#       <td>Bangladesh Near Threatened \nIndia Near Threat...</td>
#       <td>Coelops_frithii_map.pdf</td>
#       <td></td>
#       <td>Bengali: Lejhin Patanak Chamchika  English: Ta...</td>
#       <td>Hipposideridae</td>
#       <td>Colonial species with up to 16 individuals.</td>
#       <td>Forests</td>
#       <td>Hollow trees or caves. Up to 1370m.</td>
#       <td></td>
#       <td>Bangladesh, China, India, Indonesia, Malaysia,...</td>
#       <td>BANGLADESH: Sunderbans; INDIA: Meghalaya: Cher...</td>
#       <td>&gt; 20,000 sq km.</td>
#       <td>&gt; 2,000 sq km.</td>
#       <td>4 / 4. Fragmented.</td>
#       <td>Decrease in area &lt; 20% in 10 years due to defo...</t

# %%
common_names = df_chiroptera["Common names"]
